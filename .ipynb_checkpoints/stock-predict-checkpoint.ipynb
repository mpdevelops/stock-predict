# %%
import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression

quandl.ApiConfig.api_key = 'xQMKT1NAjGboPxLELevM'

df = quandl.get("WIKI/MSFT")
df = df[['Adj. Close']]

# %%
df.head()
# Out:
#             Adj. Close
# Date
# 1986-03-13    0.064720
# 1986-03-14    0.067031
# 1986-03-17    0.068187
# 1986-03-18    0.066454
# 1986-03-19    0.065298

# %%
df['Adj. Close'].plot(figsize=(15,6), color='g')
plt.legend(loc='upper left')
plt.show()

# %%
forecast = 30
df['Prediction'] = df[['Adj. Close']].shift(-forecast)

x = np.array(df.drop(['Prediction'], 1))
x = preprocessing.scale(x)

x_forecast = x[-forecast:]
x = x[:-forecast]

y = np.array(df['Prediction'])
y = y[:-forecast]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

clf = LinearRegression()
clf.fit(x_train, y_train)

confidence = clf.score(x_test, y_test)

forecast_predicted = clf.predict(x_forecast)
forecast_predicted
# Out:
# array([92.01264592, 93.01782468, 94.91535602, 94.23839889, 94.97689757,
#        93.71529566, 93.97171881, 96.35132567, 97.74626763, 96.49492264,
#        96.05387482, 95.11023761, 95.31537613, 95.92053478, 95.59231314,
#        96.14618715, 96.73083194, 98.89504336, 99.13095266, 96.71031809,
#        96.13593023, 96.47440879, 96.90519969, 95.15126532, 95.39743154,
#        94.73073134, 91.97161821, 89.29456049, 96.06413174, 91.64339658])

# %%
plt.plot(x, y)
